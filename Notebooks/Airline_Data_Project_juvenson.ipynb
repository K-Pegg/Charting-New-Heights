# %% [markdown]
# # Data understanding

# %%
import pandas as pd 
import numpy as np
df = pd.read_csv('Data/Aviation_Data.csv')
df
# Out:
# /Users/DonJuve/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (6,7,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50249 non-null  object
#  9   Airport.Name            52790 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87572 non-null  object
# ...

# %%
df['Total.Fatal.Injuries']
# Out:
# 0        2.0
# 1        4.0
# 2        3.0
# 3        2.0
# 4        1.0
#         ...
# 90343    0.0
# 90344    0.0
# 90345    0.0
# 90346    0.0
# 90347    0.0
# Name: Total.Fatal.Injuries, Length: 90348, dtype: float64

# %%
df['Total.Fatal.Injuries'].isna().sum()
# Out:
# 12860

# %%
df['Total.Fatal.Injuries'].isna().sum()
# Out:
# 12860

# %%
df['Total.Fatal.Injuries'].isna().sum()
# Out:
# 12860

# %%
df['Total.Serious.Injuries'].isna().sum()
# Out:
# 13969

# %%
df['Total.Minor.Injuries'].isna().sum()
# Out:
# 13392

# %%
df['Total.Uninjured'].isna().sum()
# Out:
# 7371

# %%
df['Report.Status'].isna().sum()
# Out:
# 7840

# %%
df['Event.Date'].isna().sum()
# Out:
# 1459

# %% [markdown]
# # Data Preparation

# %% [markdown]
# We will start by removing all the null value of the following colums of our Data Frames: 'Engine.Type','Model','Event.Date','Make','Injury.Severity','Total.Fatal.Injuries','Total.Serious.Injuries','Total.Minor.Injuries','Total.Uninjured'

# %%
df = df.dropna(subset=['Engine.Type','Model','Event.Date','Make','Injury.Severity','Total.Fatal.Injuries','Total.Serious.Injuries','Total.Minor.Injuries','Total.Uninjured' ])

# %%
df.shape
# Out:
# (68490, 31)

# %%
#verfication
df['Total.Serious.Injuries'].isna().sum()
# Out:
# 0

# %%
df['Total.Uninjured'].isna().sum()
# Out:
# 0

# %% [markdown]
# Verification of duplicate Values

# %%
df.duplicated().value_counts()
#to remove duplicates data
# Out:
# False    68490
# dtype: int64

# %%
#remove all duplicates values
df = df.drop_duplicates()

# %%
#Sanity check
df.duplicated().value_counts()
# Out:
# False    68490
# dtype: int64

# %%
df.shape
# Out:
# (68490, 31)

# %% [markdown]
# Normalization

# %%
df['Make']
# Out:
# 0                  Stinson
# 1                    Piper
# 3                 Rockwell
# 6                   Cessna
# 7                   Cessna
#                ...
# 90098               CESSNA
# 90106               CESSNA
# 90120                BEECH
# 90194    STEPHEN J HOFFMAN
# 90226             LUSCOMBE
# Name: Make, Length: 68490, dtype: object

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 6      20001218X45446           Accident      CHI81LA106  1981-08-01
# 7      20020909X01562           Accident      SEA82DA022  1982-01-01
# ...               ...                ...             ...         ...
# 90098  20221011106092           Accident      CEN23LA008  2022-10-06
# 90106  20221011106098           Accident      ERA23LA014  2022-10-08
# 90120  20221018106153           Accident      CEN23LA015  2022-10-13
# 90194  20221031106231           Accident      CEN23LA023  2022-10-29
# 90226  20221109106272           Accident      CEN23LA033  2022-11-09
#
#               Location        Country Latitude Longitude Airport.Code  \
# ...

# %%
df['Make']
# Out:
# 0                  Stinson
# 1                    Piper
# 3                 Rockwell
# 6                   Cessna
# 7                   Cessna
#                ...
# 90098               CESSNA
# 90106               CESSNA
# 90120                BEECH
# 90194    STEPHEN J HOFFMAN
# 90226             LUSCOMBE
# Name: Make, Length: 68490, dtype: object

# %%
df['Make'] = df['Make'].str.capitalize()

# %%
df['Aircraft.Category'].unique()
# Out:
# array([nan, 'Airplane', 'Helicopter', 'Glider', 'Balloon', 'Gyrocraft',
#        'Ultralight', 'Unknown', 'Weight-Shift', 'Powered Parachute',
#        'Rocket', 'Blimp', 'WSFT'], dtype=object)

# %%
#df = df[df['Aircraft.Category'].str.lower().str.contains('airplane', na=False)]zz

# %%
df_airplane = df[df['Aircraft.Category'].str.contains('Airplane', na=False)]
df_airplane
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 7      20020909X01562           Accident      SEA82DA022  1982-01-01
# 8      20020909X01561           Accident      NYC82DA015  1982-01-01
# 12     20020917X02148           Accident      FTW82FRJ07  1982-01-02
# 13     20020917X02134           Accident      FTW82FRA14  1982-01-02
# 14     20020917X02119           Accident      FTW82FPJ10  1982-01-02
# ...               ...                ...             ...         ...
# 90098  20221011106092           Accident      CEN23LA008  2022-10-06
# 90106  20221011106098           Accident      ERA23LA014  2022-10-08
# 90120  20221018106153           Accident      CEN23LA015  2022-10-13
# 90194  20221031106231           Accident      CEN23LA023  2022-10-29
# 90226  20221109106272           Accident      CEN23LA033  2022-11-09
#
#                Location        Country Latitude Longitude Airport.Code  \
# ...

# %%
df = df[df['Aircraft.Category'] == 'Airplane']
df['Aircraft.Category']
# Out:
# 7        Airplane
# 8        Airplane
# 12       Airplane
# 13       Airplane
# 14       Airplane
#            ...
# 90098    Airplane
# 90106    Airplane
# 90120    Airplane
# 90194    Airplane
# 90226    Airplane
# Name: Aircraft.Category, Length: 19883, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19883 entries, 7 to 90226
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                19883 non-null  object
#  1   Investigation.Type      19883 non-null  object
#  2   Accident.Number         19883 non-null  object
#  3   Event.Date              19883 non-null  object
#  4   Location                19883 non-null  object
#  5   Country                 19877 non-null  object
#  6   Latitude                16449 non-null  object
#  7   Longitude               16449 non-null  object
#  8   Airport.Code            13762 non-null  object
#  9   Airport.Name            14398 non-null  object
#  10  Injury.Severity         19883 non-null  object
#  11  Aircraft.damage         19456 non-null  object
#  12  Aircraft.Category       19883 non-null  object
#  13  Registration.Number     19881 non-null  object
# ...

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 7      20020909X01562           Accident      SEA82DA022  1982-01-01
# 8      20020909X01561           Accident      NYC82DA015  1982-01-01
# 12     20020917X02148           Accident      FTW82FRJ07  1982-01-02
# 13     20020917X02134           Accident      FTW82FRA14  1982-01-02
# 14     20020917X02119           Accident      FTW82FPJ10  1982-01-02
# ...               ...                ...             ...         ...
# 90098  20221011106092           Accident      CEN23LA008  2022-10-06
# 90106  20221011106098           Accident      ERA23LA014  2022-10-08
# 90120  20221018106153           Accident      CEN23LA015  2022-10-13
# 90194  20221031106231           Accident      CEN23LA023  2022-10-29
# 90226  20221109106272           Accident      CEN23LA033  2022-11-09
#
#                Location        Country Latitude Longitude Airport.Code  \
# ...

# %%
df['Make'].value_counts()
# Out:
# Cessna              6261
# Piper               3619
# Beech               1267
# Boeing               377
# Mooney               310
#                     ...
# Furgason james e       1
# Spaulding errol        1
# Siemer james h         1
# Bray verle g jr        1
# Thompson bruce d       1
# Name: Make, Length: 2868, dtype: int64

# %%
df_20 = df[df['Make'].isin(df['Make'].value_counts().nlargest(20).index)]

# %%
df_20
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 7      20020909X01562           Accident      SEA82DA022  1982-01-01
# 8      20020909X01561           Accident      NYC82DA015  1982-01-01
# 12     20020917X02148           Accident      FTW82FRJ07  1982-01-02
# 13     20020917X02134           Accident      FTW82FRA14  1982-01-02
# 15     20020917X02117           Accident      FTW82FPG08  1982-01-02
# ...               ...                ...             ...         ...
# 90089  20221011106095           Accident      CEN23LA011  2022-10-05
# 90098  20221011106092           Accident      CEN23LA008  2022-10-06
# 90106  20221011106098           Accident      ERA23LA014  2022-10-08
# 90120  20221018106153           Accident      CEN23LA015  2022-10-13
# 90226  20221109106272           Accident      CEN23LA033  2022-11-09
#
#                Location        Country Latitude Longitude Airport.Code  \
# ...

# %%
#df = df[df['Aircraft.Category'] == 'Airplane']
df_personal = df_20[df_20['Purpose.of.flight'] == 'Personal']

# %%
df_personal
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 7      20020909X01562           Accident      SEA82DA022  1982-01-01
# 12     20020917X02148           Accident      FTW82FRJ07  1982-01-02
# 13     20020917X02134           Accident      FTW82FRA14  1982-01-02
# 15     20020917X02117           Accident      FTW82FPG08  1982-01-02
# 17     20020917X01656           Accident      ANC82FAG14  1982-01-02
# ...               ...                ...             ...         ...
# 90089  20221011106095           Accident      CEN23LA011  2022-10-05
# 90098  20221011106092           Accident      CEN23LA008  2022-10-06
# 90106  20221011106098           Accident      ERA23LA014  2022-10-08
# 90120  20221018106153           Accident      CEN23LA015  2022-10-13
# 90226  20221109106272           Accident      CEN23LA033  2022-11-09
#
#               Location        Country Latitude Longitude Airport.Code  \
# ...

# %%
df_business = df_20[df_20['Purpose.of.flight'] == 'Business']

# %%
#filtered_df = df[(df['Total.Fatal.Injuries'] == 0) & (df['Total.Serious.Injuries'] == 0) & (df['Total.Minor.Injuries'] == 0)]

# %%
df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %% [markdown]
# Safety Metric Calculation :

# %%
# first lets determine the total of the overall Injuries
df_20['Total.Injuries'] = df_20[['Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries']].sum(axis=1)
# Out:
# <ipython-input-38-c31a3e951e21>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_20['Total.Injuries'] = df_20[['Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries']].sum(axis=1)

# %%
df_20['Fatality.Rate'] = df_20['Total.Fatal.Injuries'] / df['Total.Injuries']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total.Injuries'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-5dac42d3e356> in <module>
# ...

# %%
#  Calculate Safety Metrics
#df['Total.Injuries'] = df[safety_columns[:-1]].sum(axis=1)
df_20.head()

# %% [markdown]
# Group data by categorie using the colummn Make

# %%
df_new = df.groupby('Make')

# %%
#creating the year column
df_20['Year'] = df_20['Event.Date'].str[:4]
print(df_20['Year'])

# %%
ranked_companies = df_new[['Total.Fatal.Injuries', 'Total.Injuries', 'Fatality.Rate']].sum()
ranked_companies['Incident.Count'] = df_new.size()
ranked_companies['Rank'] = ranked_companies['Total.Fatal.Injuries'].rank(ascending=True)

# %%
print(ranked_companies.sort_values(by='Rank'))

# %%
#df.to_csv('df_airplane_JE.csv')

# %%
import matplotlib.pyplot as plt

#fig, axs = plt.subplots(1, 3, figsize=(10, 18)) 
plt.figure(figsize=(10, 6))
                        
plt.bar(df_20['Make'], df_20['Total.Injuries'], color='blue')
plt.xlabel('Airlines companies')
plt.ylabel('total Injuries')
plt.title('Total injuries vs Make')
plt.tick_params (axis="x", labelrotation=90)                       
plt.show()

# %%
df_20['Make'].values

# %%
df_20['Total.Injuries']

# %%
#fig, axs = plt.subplots(1, 3, figsize=(10, 18)) 
plt.figure(figsize=(10, 6))
plt.bar(df_20['Year'], df_20['Total.Fatal.Injuries'],color='blue')

#plt.xlabel(df_20['Make'].values)
plt.ylabel('total Injuries')
plt.title('Total Fatal injuries vs Years')
plt.tick_params (axis="x", labelrotation=90)   

plt.show()

# %% [markdown]
# fatalities vs phase of flight

# %%
df_20['Broad.phase.of.flight']

# %%
#fig, axs = plt.subplots(1, 3, figsize=(10, 18)) 
plt.figure(figsize=(10, 6))
plt.bar(df_20['Broad.phase.of.flight'], df_20['Total.Fatal.Injuries'],color='blue')

#plt.xlabel(df_20['Make'].values)
plt.ylabel('total Injuries')
plt.title('Phase of flight vs Fatal Injuries')
plt.tick_params (axis="x", labelrotation=90)   

plt.show()

# %% [markdown]
# fatalities vs phase of flight (as a company we need to focus on this particular phase)
# number injured per per accident per year (fatal/severe/minor/uninjured)
# injured vs purpose of flight
# severity of accidents by type

# %%
df_20.keys()

# %%
df_20['Fatality.Rate']
df['your_column'] = df['your_column'].fillna(0)

# %%
#fatalities vs phase of flight 
import matplotlib.pyplot as plt
x = df_20['Fatality.Rate'].astype(int)
#fig, axs = plt.subplots(1, 3, figsize=(10, 18)) 
plt.figure(figsize=(10, 6))
                        
plt.scatter(x, df_20['Broad.phase.of.flight'], color='blue')
plt.xlabel('Airlines companies')
plt.ylabel('total Injuries')
plt.title('Total injuries by Airlines')
plt.tick_params (axis="x", labelrotation=90)                       
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import math 
  
# Using Numpy to create an array X 
X = df_20['Make'] 
  
# Assign variables to the y axis part of the curve 
y = df_20['Year']
z = df_20['Total.Fatal.Injuries']
  
# Plotting both the curves simultaneously 
plt.plot(X, y, color='r', label='Year') 
plt.plot(X, z, color='g', label='Total Fatal Injuries') 
plt.tick_params (axis="x", labelrotation=90)  
# Naming the x-axis, y-axis and the whole graph 
plt.xlabel("Angle") 
plt.ylabel("Magnitude") 
plt.title("Sine and Cosine functions") 
  
# Adding legend, which helps us recognize the curve according to it's color 
plt.legend() 
  
# To load the display window 
plt.show()

# %%
df['Amateur.Built'].value_counts()

# %%
df['Make'].value_counts()

# %%
df_airplane = pd.read_csv('Data/Airplane_data.csv')

# %%
df_airplane

# %%
list(df_airplane['Make'].unique()[125:150])

# %%
df_airplane['Make']=df_airplane['Make'].replace("Rockwell International", "Rockwell Intl")

# %%
list(df_airplane['Make'].unique()[125:150])

# %%
df_airplane['Make']=df_airplane['Make'].replace("Rockwell int't", "Rockwell Intl")
df_airplane['Make']=df_airplane['Make'].replace('Rockwell international', "Rockwell Intl")

# %%
list(df_airplane['Make'].unique()[125:150])

# %%
df_airplane['Make'].value_counts()[30:60]

# %%
df_airplane['Make'].value_counts()

# %%
df_airplane['Make']=df_airplane['Make'].replace('Rockwell', "Rockwell Intl")
df_airplane['Make']=df_airplane['Make'].replace('Rockwell comdr', "Rockwell Intl")
df_airplane['Make']=df_airplane['Make'].replace('Rockwell commander', "Rockwell Intl")


df_airplane['Make']=df_airplane['Make'].replace("Douglas", "Mcdonnell Douglas")
df_airplane['Make']=df_airplane['Make'].replace("Mcdonnell douglas", "Mcdonnell Douglas")
df_airplane['Make']=df_airplane['Make'].replace('Mcdonnell-douglas', "Mcdonnell Douglas")

df_airplane['Make']=df_airplane['Make'].replace('Bombardier inc', "Bombardier")
df_airplane['Make']=df_airplane['Make'].replace("Bombardier, inc.", "Bombardier")

df_airplane['Make']=df_airplane['Make'].replace("Cessna aircraft co", 'Cessna')
df_airplane['Make']=df_airplane['Make'].replace("Cessna aircraft company", 'Cessna')
df_airplane['Make']=df_airplane['Make'].replace("Cessna aircraft", 'Cessna')

df_airplane['Make']=df_airplane['Make'].replace("Gulfstream aerospace", 'Gulfstream')
df_airplane['Make']=df_airplane['Make'].replace("Gulfstream-schweizer a/c corp", 'Gulfstream')
df_airplane['Make']=df_airplane['Make'].replace("Gulfstream american corp", 'Gulfstream')
df_airplane['Make']=df_airplane['Make'].replace("Gulfstream-schweizer", 'Gulfstream')
df_airplane['Make']=df_airplane['Make'].replace('Gulfstream american', "Gulfstream")

df_airplane['Make']=df_airplane['Make'].replace("Czech aircraft works spol sro", 'Czech aircraft')
df_airplane['Make']=df_airplane['Make'].replace("Czech sport aircraft as", 'Czech aircraft')
df_airplane['Make']=df_airplane['Make'].replace("zech aircraft works", 'Czech aircraft')

df_airplane['Make']=df_airplane['Make'].replace("Learjet inc", "Learjet")
df_airplane['Make']=df_airplane['Make'].replace("Gates learjet corp.", "Learjet")
df_airplane['Make']=df_airplane['Make'].replace('Gates learjet', "Learjet")


df_airplane['Make']=df_airplane['Make'].replace("The boeing company", "Boeing")
df_airplane['Make']=df_airplane['Make'].replace("Boeing stearman", "Boeing")
df_airplane['Make']=df_airplane['Make'].replace('Smith mini', "Smith")
df_airplane['Make']=df_airplane['Make'].replace('Smith aerostar', "Smith")
df_airplane['Make']=df_airplane['Make'].replace('Smith miniplane', "Smith")
df_airplane['Make']=df_airplane['Make'].replace('Ted smith', "Smith")

# %%
df_airplane['Make'].value_counts()[200:250]

# %%
df_airplane

# %%
list(df_airplane['Make'].unique()[50:100])

# %%
df_airplane.to_csv('Airplane_data.csv')

# %%
df_airplane

# %%
# Select a numerical column for the histogram
numerical_column = 'Total.Injuries'

# Sort the DataFrame by the numerical column and get the top 10 values
top_10_values = df.nlargest(10, numerical_column)

# Create a histogram
plt.figure(figsize=(10, 6))
plt.hist(top_10_values[numerical_column], bins=10, color='blue', edgecolor='black')

# Set labels and title
plt.xlabel('Total Injuries')
plt.ylabel('Frequency')
plt.title('Histogram of Top 10 Total Injuries')

# Show the plot
plt.show()

# %% [markdown]
# Merci!
